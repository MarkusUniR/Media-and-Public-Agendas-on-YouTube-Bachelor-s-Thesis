# %% [markdown]
# The purpose of the following code was to use the video urls, that were fetched in notebook 1 (Scraping the relevant YouTube URLs) to scrape their metadata. Parts of this code were generated with the help of ChatGPT and altered for the specific needs of this study. The main tool used to scrape the links was YouTube Data API v3.

# %%
# !pip install isodate
# Out:
# Collecting isodate
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate
# Successfully installed isodate-0.7.2

# %%
api_key = "api_key" # again the real api key was replaced

with open("DW_URLs.txt", "r") as f:
    video_urls_list = [line.strip() for line in f]

print(f"{len(video_urls_list)} URLs loaded")
print(video_urls_list[:5])
# Out:
# 4302 URLs loaded
# ['https://www.youtube.com/watch?v=wLl0QLyZ-Ec', 'https://www.youtube.com/watch?v=5yj3k1xIB68', 'https://www.youtube.com/watch?v=yqqCS-U5QqY', 'https://www.youtube.com/watch?v=eWedRFWb7To', 'https://www.youtube.com/watch?v=9Pp4uXFQKH4']

# %%
import pandas as pd
from googleapiclient.discovery import build
from urllib.parse import urlparse, parse_qs
import isodate

def extract_video_id(url):
    parsed = urlparse(url)
    if parsed.hostname == "youtu.be":
        return parsed.path[1:]
    elif parsed.hostname in ["www.youtube.com", "youtube.com"]:
        params = parse_qs(parsed.query)
        return params.get("v", [None])[0]
    return None

def scrape_video_metadata(api_key, video_urls):
    youtube = build("youtube", "v3", developerKey=api_key)

    # Extract and clean video IDs
    video_ids = list(filter(None, [extract_video_id(url) for url in video_urls]))
    if not video_ids:
        raise ValueError("No valid video IDs found.")

    # Process in batches of 50 due to API restrictions
    all_data = []
    for i in range(0, len(video_ids), 50):
        batch_ids = video_ids[i:i + 50]
        request = youtube.videos().list(
            part="snippet,statistics,contentDetails",
            id=",".join(batch_ids),
            maxResults=50
        )
        response = request.execute()

        for item in response.get("items", []):
            snippet = item["snippet"]
            stats = item.get("statistics", {})
            content_details = item.get("contentDetails", {})
            duration_iso = content_details.get("duration")

            # Parse duration to seconds
            duration_seconds = int(isodate.parse_duration(duration_iso).total_seconds()) if duration_iso else None

            video_data = {
                "video_id": item["id"],
                "video_url": f"https://www.youtube.com/watch?v={item['id']}",
                "title": snippet.get("title"),
                "description": snippet.get("description"),
                "published_at": snippet.get("publishedAt"),
                "view_count": int(stats.get("viewCount", 0)),
                "like_count": int(stats.get("likeCount", 0)),
                "comment_count": int(stats.get("commentCount", 0)),
                "video_length": duration_seconds
            }
            all_data.append(video_data)

    return pd.DataFrame(all_data)

# %%
DW_Video_data = scrape_video_metadata(api_key, video_urls_list)

# %%
print(len(DW_Video_data))
DW_Video_data.to_csv("DW_Video_data.csv", index=False)
from google.colab import files
files.download("DW_Video_data.csv")
DW_Video_data
# Out:
# 4271
#          video_id                                    video_url  \
# 0     wLl0QLyZ-Ec  https://www.youtube.com/watch?v=wLl0QLyZ-Ec
# 1     5yj3k1xIB68  https://www.youtube.com/watch?v=5yj3k1xIB68
# 2     yqqCS-U5QqY  https://www.youtube.com/watch?v=yqqCS-U5QqY
# 3     eWedRFWb7To  https://www.youtube.com/watch?v=eWedRFWb7To
# 4     9Pp4uXFQKH4  https://www.youtube.com/watch?v=9Pp4uXFQKH4
# ...           ...                                          ...
# 4266  Ii7w7VNFo2s  https://www.youtube.com/watch?v=Ii7w7VNFo2s
# 4267  Qy9QQgqSQFg  https://www.youtube.com/watch?v=Qy9QQgqSQFg
# 4268  ojfy9oanvOs  https://www.youtube.com/watch?v=ojfy9oanvOs
# 4269  rrFCUxvDV6s  https://www.youtube.com/watch?v=rrFCUxvDV6s
# 4270  Ei5lEmXff3k  https://www.youtube.com/watch?v=Ei5lEmXff3k
#
#                                                   title  \
# 0     Ex-Mitarbeiter von AfD-Politiker Maximilian Kr...
# 1     Ukraine: Wie russische Drohnen die Versorgung ...
# 2     Wie Putin Schüler für den Drohnenkrieg benutzt...
# 3     Jared Kushner will in Albanien ein Luxus-Resso...
# 4     Iran zwingt Flüchtlinge zur Rückkehr nach Afgh...
# ...                                                 ...
# 4266   Coronavirus: Deutsche in Quarantäne | DW Deutsch
# 4267  Coronavirus in China: Deutsche werden aus Wuha...
# 4268  Coronavirus in China: Sebastian steckt in Wuha...
# 4269  Coronavirus in China: Deutscher Student berich...
# 4270  Coronavirus aus China: DW spricht mit einem De...
#
#                                             description          published_at  \
# 0     Gegen einen ehemaligen Mitarbeiter des AfD-Pol...  2025-08-05T14:01:25Z
# 1     Verletzte ukrainische Soldaten sitzen oft im K...  2025-08-05T12:02:57Z
# 2     Russland überzieht die Ukraine mit massiven Dr...  2025-08-04T16:34:59Z
# 3     Trumps Schwiegersohn, Jared Kushner, will in A...  2025-08-01T18:00:01Z
# 4     Feindseligkeit, steigende Preise und politisch...  2025-08-01T13:30:08Z
# ...                                                 ...                   ...
# 4266  Deutschland hat mit der Evakuierung seiner Sta...  2020-02-03T10:01:13Z
# 4267  Die Weltgesundheitsorganisation (WHO) hat ange...  2020-01-31T17:10:25Z
# 4268  British Airways und Lufthansa - die großen eur...  2020-01-30T09:13:14Z
# 4269  Die Zahl der Todesopfer des Corona-Virus steig...  2020-01-29T12:59:34Z
# 4270  Die Zahl der Todesopfer des Corona-Virus steig...  2020-01-28T15:35:49Z
#
#       view_count  like_count  comment_count  video_length
# 0          15479         237            299          1001
# 1           9598         153             60           201
# 2          24052         434            197           871
# 3          11699         186             43           404
# 4          21734         250            165           183
# ...          ...         ...            ...           ...
# 4266       30046         254            151           290
# 4267      302611        1568            379           589
# 4268      102134         663            323           752
# 4269      186828        1179            549           649
# 4270      521284        4866           1601           304
#
# [4271 rows x 9 columns]

# %%
with open("BILD_URLs.txt", "r") as f:
    BILD_urls_list = [line.strip() for line in f]

print(f"{len(BILD_urls_list)} URLs loaded")

BILD_Video_data = scrape_video_metadata(api_key, BILD_urls_list)
print(len(BILD_Video_data))
print(BILD_Video_data)
BILD_Video_data.to_csv("BILD_Video_data.csv", index=False)
from google.colab import files
files.download("BILD_Video_data.csv")
# Out:
# 14229 URLs loaded
# 13884
#           video_id                                    video_url  \
# 0      Jf7BcLknC1I  https://www.youtube.com/watch?v=Jf7BcLknC1I
# 1      KFtEWl4s-sk  https://www.youtube.com/watch?v=KFtEWl4s-sk
# 2      k5wLZkD9NZM  https://www.youtube.com/watch?v=k5wLZkD9NZM
# 3      3j1EFKPSGoE  https://www.youtube.com/watch?v=3j1EFKPSGoE
# 4      QkGZYUbNnGE  https://www.youtube.com/watch?v=QkGZYUbNnGE
# ...            ...                                          ...
# 13879  eJmhwxEZSI0  https://www.youtube.com/watch?v=eJmhwxEZSI0
# 13880  f7AU1yQQXhs  https://www.youtube.com/watch?v=f7AU1yQQXhs
# 13881  5CGR376LRr8  https://www.youtube.com/watch?v=5CGR376LRr8
# 13882  xzOehwU17V0  https://www.youtube.com/watch?v=xzOehwU17V0
# 13883  7RPL-IBo03Q  https://www.youtube.com/watch?v=7RPL-IBo03Q
#
#                                                    title  \
# 0      Leopard und Puma im Einsatz: Bundeswehr probt ...
# 1      Jagd auf jüdische Passagiere: Islamisten-Mob s...
# 2      Iran gibt Huthis Angriffsbefehl auf Israel | B...
# 3      Paul Ronzheimer mitten im Kampfgebiet: Heftige...
# 4      Ukraine kämpft um ihren Brückenkopf | BILD-Lag...
# ...                                                  ...
# 13879  Feuer-Inferno in Affenhaus: 30 Tiere sterben i...
# 13880  Massencrash auf der A1: Person stirbt nach Kar...
# 13881  Silvester in Berlin: Kugelbomben-Böller explod...
# 13882  Offenbar Linksradikale greifen Polizisten an |...
# 13883  Heftiger Drift: Abschleppdienst entkommt nur k...
#
#                                              description  \
# 0      Hier schießen der Leopard und der Puma-Panzer ...
# 1      Erschütternde Szenen an einem Flughafen in der...
# 2      Die De-Facto-Regierung des Jemen hat Israel am...
# 3      Maschinengewehrfeuer, Kampfjets und Panzer: Pa...
# 4      Ukrainische Soldaten versuchen mit aller Kraft...
# ...                                                  ...
# 13879  Feuer-Tragödie an Neujahr! Mehr als 30 Tiere f...
# 13880  In der nebligen Neujahrsnacht ist es überall i...
# 13881  In Berlin-Neukölln am Hermannplatz war die Lag...
# 13882  Für Polizisten, Feuerwehrleute und medizinisch...
# 13883  Es ist der erste Weihnachtstag 2019, als ein P...
#
#                published_at  view_count  like_count  comment_count  \
# 0      2023-11-01T14:00:19Z      215254        1794            479
# 1      2023-11-01T16:00:17Z       28517         258            180
# 2      2023-11-01T15:00:46Z      498976        4708           1877
# 3      2023-11-01T17:00:02Z        6523         100             66
# 4      2023-11-01T17:00:18Z      367488        5635           1706
# ...                     ...         ...         ...            ...
# 13879  2020-01-01T15:15:00Z      160960        2448            541
# 13880  2020-01-01T14:42:29Z       22470         598             65
# 13881  2020-01-01T12:51:28Z     1107783       11484           1560
# 13882  2020-01-01T12:40:19Z       38687         549            128
# 13883  2020-01-01T09:00:01Z       13262         307             29
#
#        video_length
# 0               436
# 1                97
# 2               841
# 3                82
# 4               676
# ...             ...
# 13879           112
# 13880           129
# 13881            44
# 13882            53
# 13883            80
#
# [13884 rows x 9 columns]

# %%
# Filter only relevant years
def filter_years(df):
    df["published_at"] = pd.to_datetime(df["published_at"], errors="coerce")
    return df[df["published_at"].dt.year.isin([2020, 2021, 2022, 2023])]


BILD_video_data_cleaned = filter_years(BILD_Video_data)
DW_video_data_cleaned = filter_years(DW_Video_data)

# %%
BILD_video_data_cleaned.to_csv("BILD_video_data_cleaned.csv", index=False)
DW_video_data_cleaned.to_csv("DW_video_data_cleaned.csv", index=False)

files.download("BILD_video_data_cleaned.csv")
files.download("DW_video_data_cleaned.csv")
